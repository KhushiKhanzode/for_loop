# %%
for i in range(5,0,-1) :
    print("* "*i)
for i in range(2,6):
    print("* "*i)
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
for i in range(10) :
    if i%2!=0 :
        print("* "*i)
# Out:
# *
# * * *
# * * * * *
# * * * * * * *
# * * * * * * * * *

# %%
a ="Naresh"
for i in a :
    print(i)
# Out:
# N
# a
# r
# e
# s
# h

# %%
for i in range(1,11) :
    if i%2==0 :
        print("Even number:",i)
    else :
        print("Odd number:",i)
# Out:
# Odd number: 1
# Even number: 2
# Odd number: 3
# Even number: 4
# Odd number: 5
# Even number: 6
# Odd number: 7
# Even number: 8
# Odd number: 9
# Even number: 10

# %%
for i in range(1,11) :
    print(i*i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
a ="yahoo.com"
for i in a :
    if'.' in i:
        break
    print(i,end='')
# Out:
# yahoo

# %%
for i in range(6,0,-1) : #(start,stop,step)
    print('* '*i)
# Out:
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range (6) :
    print('* '*i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
a = 1
for i in range(5,0,-1) :
        print(" "*i+"*"*a,end='')
        a += 2
        print()
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
